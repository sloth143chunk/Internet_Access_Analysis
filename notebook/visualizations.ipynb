# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
internet_access_df=pd.read_csv('../resources/regression_ml_model/merged_internet_access.csv')
internet_access_df.head()
# Out:
#            geo_id                      county_name  population  sex_total_men  \
# 0  0500000US06033          Lake County, California       64148          31879
# 1  0500000US06043      Mariposa County, California       17540           8920
# 2  0500000US06115          Yuba County, California       75493          38468
# 3  0500000US06013  Contra Costa County, California     1133247         553701
# 4  0500000US06035        Lassen County, California       31185          20671
#
#    sex_total_women  race_hispanic_or_latino  race_not_hispanic_or_latino  \
# 0            32269                    12830                        51318
# 1             8620                     1909                        15631
# 2            37025                    20990                        54503
# 3           579546                   288101                       845146
# 4            10514                     5834                        25351
#
#    race_american_indian_and_alaska_native  race_asian  \
# ...

# %% [markdown]
# # Census and Demographic Box and Whisker Plot

# %%
list(internet_access_df.columns)
# Out:
# ['geo_id',
#  'county_name',
#  'population',
#  'sex_total_men',
#  'sex_total_women',
#  'race_hispanic_or_latino',
#  'race_not_hispanic_or_latino',
#  'race_american_indian_and_alaska_native',
#  'race_asian',
#  'race_black_or_african_american',
#  'race_native_hawaiian_and_other_pacific_islander',
#  'race_some_other_race',
#  'race_two_or_more',
#  'race_two_or_more_excluding_some_ther_and_three_or_more',
#  'race_two_or_more_including_some_other',
#  'race_white_alone',
#  'occupation_population_16_and_over_total',
#  'occupation_management_business_science_and_arts',
#  'occupation_service',
#  'occupation_sales_and_office',
#  'occupation_natural_resources_construction_and_maintenance',
#  'occupation_production_transporation_and_material_moving',
#  'hh_with_computer_and_internet_total',
#  'hh_with_computer',
#  'hh_with_bb_internet_subscription',
#  'industry_agriculture_forestry_fishing_and_hunting_and_mining',
#  'industry_construction',
#  'industry_manufacturing',
# ...

# %%
internet_access_df.boxplot(column=['population', 'sex_total_men',
 'sex_total_women',
 ], grid=True, rot=90, fontsize=10, showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=['race_hispanic_or_latino',
 'race_not_hispanic_or_latino', 'race_white_alone',
 'race_american_indian_and_alaska_native',
 'race_asian',
 'race_black_or_african_american',
 'race_native_hawaiian_and_other_pacific_islander',], grid=True, rot=90, fontsize=15, showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[ 'race_some_other_race',
 'race_two_or_more',
 'race_two_or_more_excluding_some_ther_and_three_or_more',
 'race_two_or_more_including_some_other',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'occupation_population_16_and_over_total',
 'occupation_management_business_science_and_arts',
 'occupation_service',
 'occupation_sales_and_office',
 'occupation_natural_resources_construction_and_maintenance',
 'occupation_production_transporation_and_material_moving',
 ], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'hh_with_computer_and_internet_total',
 'hh_with_computer',
 'hh_with_bb_internet_subscription',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'industry_agriculture_forestry_fishing_and_hunting_and_mining',
 'industry_construction',
 'industry_manufacturing',
 'industry_wholesale_trade',
 'industry_retail_trade',
 'industry_transportation_and_warehousing_and_utilities',
 'industry_information',
 'industry_finance_and_insurance_real_estate_and_rental_and_leasing',
 'industry_professional_scientific_management_administrative_and_waste_management_services',
 'industry_educational_services_health_care_and_social_assistance',
 'industry_arts_entertainment_recreation_accommodation_and_food_services',
 'industry_other_services_except_public_administration',
 'industry_public_administration',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=['hh_median_income',
 'hh_mean_income',
 'hh_with_income_less_than_10000',
 'hh_with_income_10000-14999',
 'hh_with_income_15000-24999',
 'hh_with_income_25000-34999',
 'hh_with_income_35000-49999',
 'hh_with_income50000-74999',
 'hh_with_income_75000-99999',
 'hh_with_income_100000-149999',
 'hh_with_income_150000-199999',
 'hh_with_income_200000_and_greater',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'hh_with_income_total', 'family_structure_hh_total', 'hh_median_income',
 'hh_mean_income',
 'family_structure_hh_with_one_or_more_under_18',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'employment_16_and_over_in_labor_force', 'occupation_population_16_and_over_total',
 'employment_employed',
 'employment_unemployed',
 'employment_not_in_labor_force',
 'employment_%_unemployment_rate',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 '%_eduction_population_25_and_over_less_than_9th_grade',
 '%_eduction_population_25_and_over_9th-12th_no_diploma',
 '%_eduction_population_25_and_over_high_school_graduate',
 '%_eduction_population_25_and_over_some_college_no_degree',
 '%_eduction_population_25_and_over_associates_degree',
 '%_eduction_population_25_and_over_bachelors_degree',
 '%_eduction_population_25_and_over_graduate_or_professional_degree',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'disability_population_under_18',
 'disability_population_18-64',
 'disability_population_65_and_over',
 'disability_under_18_with_disability',
 'disability_18-64_with_disability',
 'disability_64_and_over_with_disability',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'citizenship_native_born',
 'citizenship_foreign_born',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %%
internet_access_df.boxplot(column=[
 'age_under_5',
 'age_5-9',
 'age_10-14',
 'age_15-19',
 'age_20-24',
 'age_25-34',
 'age_35-44',
 'age_45-54',
 'age_55-59',
 'age_60-64',
 'age_65-74',
 'age_75-84',
 'age_85_and_over',], grid=True, rot=90, fontsize=10,  showfliers=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # FCC Download Speed Bar Graphs

# %%
fcc_df=pd.read_csv('../resources/fcc/fcc_ml_by_county.csv')
fcc_df.head()
# Out:
#            geo_id  dl_speed   has_0   has_1   has_2  has_3more  has_access  \
# 0  0500000US06001      25.0       0       8    1106    1670215     1671329
# 1  0500000US06001     100.0   16847  107030  414559    1132893     1654482
# 2  0500000US06001     250.0   69107  692197  741295     168730     1602222
# 3  0500000US06001    1000.0  778330  807092   84097       1810      892999
# 4  0500000US06005      25.0       0       1     957      38793       39751
#
#    total_pop  urban_pop  rural_pop  total_access_pop_percent  \
# 0    1671329    1657705      13624                  1.000000
# 1    1671329    1657705      13624                  0.989920
# 2    1671329    1657705      13624                  0.958651
# 3    1671329    1657705      13624                  0.534305
# 4      39751      14768      24983                  1.000000
#
#    urban_access_pop_percent  rural_access_pop_percent
# 0                  1.000000                  1.000000
# ...

# %%
list(fcc_df.columns)
# Out:
# ['geo_id',
#  'dl_speed',
#  'has_0',
#  'has_1',
#  'has_2',
#  'has_3more',
#  'has_access',
#  'total_pop',
#  'urban_pop',
#  'rural_pop',
#  'total_access_pop_percent',
#  'urban_access_pop_percent',
#  'rural_access_pop_percent']

# %%
fcc_df.head()
# Out:
#            geo_id  dl_speed   has_0   has_1   has_2  has_3more  has_access  \
# 0  0500000US06001      25.0       0       8    1106    1670215     1671329
# 1  0500000US06001     100.0   16847  107030  414559    1132893     1654482
# 2  0500000US06001     250.0   69107  692197  741295     168730     1602222
# 3  0500000US06001    1000.0  778330  807092   84097       1810      892999
# 4  0500000US06005      25.0       0       1     957      38793       39751
#
#    total_pop  urban_pop  rural_pop  total_access_pop_percent  \
# 0    1671329    1657705      13624                  1.000000
# 1    1671329    1657705      13624                  0.989920
# 2    1671329    1657705      13624                  0.958651
# 3    1671329    1657705      13624                  0.534305
# 4      39751      14768      24983                  1.000000
#
#    urban_access_pop_percent  rural_access_pop_percent
# 0                  1.000000                  1.000000
# ...

# %%
fcc_df['dl_speed'].unique()
# Out:
# array([  25.,  100.,  250., 1000.])

# %%
columns=fcc_df['dl_speed'].unique()
rows=['has_0', 'has_1', 'has_2', 'has_3more']
# rows=df['broadband_tech'].unique()
fig, ax=plt.subplots(len(rows), len(columns), figsize=(20, 10), sharex=True, sharey=True)
plt.tight_layout()
for i in range(len(columns)): 
    for j in range(len(rows)):
        grouped=fcc_df[fcc_df['dl_speed']==columns[i]].groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
        grouped_pct=grouped.divide(grouped.loc[:, 'total_pop'], axis=0)
#         grouped_pct['has_3more'].hist()
        grouped_pct[rows[j]].hist(ax=ax[j][i])
        ax[j][i].set_title(f'{rows[j]} X {columns[i]}mbs')
        ax[j][i].set_xlim([0, 1])
# Out:
# <ipython-input-75-f1d54ecedc61>:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=fcc_df[fcc_df['dl_speed']==columns[i]].groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
# <ipython-input-75-f1d54ecedc61>:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=fcc_df[fcc_df['dl_speed']==columns[i]].groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
# <ipython-input-75-f1d54ecedc61>:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=fcc_df[fcc_df['dl_speed']==columns[i]].groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
# ...

# %%
# previous download speed and code for various broadband tech types
columns=df['dl_speed'].unique()
rows=['has_0', 'has_1', 'has_2', 'has_3more']
# rows=df['broadband_tech'].unique()
fig, ax=plt.subplots(len(rows), len(columns), figsize=(20, 10), sharex=True, sharey=True)
plt.tight_layout()
for i in range(len(columns)): 
    for j in range(len(rows)):
        grouped=df[(df['broadband_tech']=='Wireless')&(df['dl_speed']==columns[i])].groupby(['geo_id', 'broadband_tech', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
        grouped_pct=grouped.divide(grouped.loc[:, 'total_pop'], axis=0)
#         grouped_pct['has_3more'].hist()
        grouped_pct[rows[j]].hist(ax=ax[j][i])
        ax[j][i].set_title(f'{rows[j]} X {columns[i]}mbs')
        ax[j][i].set_xlim([0, 1])

# %%
# previous download speed and code for various broadband tech types
columns=df['dl_speed'].unique()
rows=['has_0', 'has_1', 'has_2', 'has_3more']
# rows=df['broadband_tech'].unique()
fig, ax=plt.subplots(len(rows), len(columns), figsize=(20, 10), sharex=True, sharey=True)
plt.tight_layout()
for i in range(len(columns)): 
    for j in range(len(rows)):
        grouped=df[(df['broadband_tech']=='Cable')&(df['dl_speed']==columns[i])].groupby(['geo_id', 'broadband_tech', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
        grouped_pct=grouped.divide(grouped.loc[:, 'total_pop'], axis=0)
#         grouped_pct['has_3more'].hist()
        grouped_pct[rows[j]].hist(ax=ax[j][i])
        ax[j][i].set_title(f'{rows[j]} X {columns[i]}mbs')
        ax[j][i].set_xlim([0, 1])

# %%
grouped=fcc_df.groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
grouped
# Out:
# <ipython-input-74-b7ccb4edce4d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=fcc_df.groupby(['geo_id', 'dl_speed'])['has_0', 'has_1', 'has_2', 'has_3more', 'total_pop'].sum()
#                           has_0   has_1   has_2  has_3more  total_pop
# geo_id         dl_speed
# 0500000US06001 25.0           0       8    1106    1670215    1671329
#                100.0      16847  107030  414559    1132893    1671329
#                250.0      69107  692197  741295     168730    1671329
#                1000.0    778330  807092   84097       1810    1671329
# 0500000US06005 25.0           0       1     957      38793      39751
# ...                         ...     ...     ...        ...        ...
# 0500000US06113 1000.0    134185   68699   17616          0     220500
# 0500000US06115 25.0           0       0     368      78300      78668
# ...

# %%
fcc_df[fcc_df['geo_id']=='0500000US06001']
# Out:
#            geo_id  dl_speed   has_0   has_1   has_2  has_3more  has_access  \
# 0  0500000US06001      25.0       0       8    1106    1670215     1671329
# 1  0500000US06001     100.0   16847  107030  414559    1132893     1654482
# 2  0500000US06001     250.0   69107  692197  741295     168730     1602222
# 3  0500000US06001    1000.0  778330  807092   84097       1810      892999
#
#    total_pop  urban_pop  rural_pop  total_access_pop_percent  \
# 0    1671329    1657705      13624                  1.000000
# 1    1671329    1657705      13624                  0.989920
# 2    1671329    1657705      13624                  0.958651
# 3    1671329    1657705      13624                  0.534305
#
#    urban_access_pop_percent  rural_access_pop_percent
# 0                  1.000000                  1.000000
# 1                  0.992846                  0.633955
# 2                  0.962639                  0.473429
# 3                  0.537115                  0.192381

# %%
grouped.index
# Out:
# MultiIndex([('0500000US06001',   25.0),
#             ('0500000US06001',  100.0),
#             ('0500000US06001',  250.0),
#             ('0500000US06001', 1000.0),
#             ('0500000US06005',   25.0),
#             ('0500000US06005',  100.0),
#             ('0500000US06005',  250.0),
#             ('0500000US06005', 1000.0),
#             ('0500000US06007',   25.0),
#             ('0500000US06007',  100.0),
#             ...
#             ('0500000US06111',  250.0),
#             ('0500000US06111', 1000.0),
#             ('0500000US06113',   25.0),
#             ('0500000US06113',  100.0),
#             ('0500000US06113',  250.0),
#             ('0500000US06113', 1000.0),
#             ('0500000US06115',   25.0),
#             ('0500000US06115',  100.0),
#             ('0500000US06115',  250.0),
#             ('0500000US06115', 1000.0)],
#            names=['geo_id', 'dl_speed'], length=216)

# %%
grouped_pct=grouped.divide(grouped.loc[:, 'total_pop'], axis=0)
grouped_pct.loc['0500000US06113']
# Out:
#              has_0     has_1     has_2  has_3more  total_pop
# dl_speed
# 25.0      0.000000  0.000005  0.059379   0.940617        1.0
# 100.0     0.131701  0.198644  0.417587   0.252068        1.0
# 250.0     0.332458  0.536871  0.126980   0.003692        1.0
# 1000.0    0.608549  0.311560  0.079891   0.000000        1.0

# %%
grouped_pct.index
# Out:
# MultiIndex([('0500000US06001',   25.0),
#             ('0500000US06001',  100.0),
#             ('0500000US06001',  250.0),
#             ('0500000US06001', 1000.0),
#             ('0500000US06005',   25.0),
#             ('0500000US06005',  100.0),
#             ('0500000US06005',  250.0),
#             ('0500000US06005', 1000.0),
#             ('0500000US06007',   25.0),
#             ('0500000US06007',  100.0),
#             ...
#             ('0500000US06111',  250.0),
#             ('0500000US06111', 1000.0),
#             ('0500000US06113',   25.0),
#             ('0500000US06113',  100.0),
#             ('0500000US06113',  250.0),
#             ('0500000US06113', 1000.0),
#             ('0500000US06115',   25.0),
#             ('0500000US06115',  100.0),
#             ('0500000US06115',  250.0),
#             ('0500000US06115', 1000.0)],
#            names=['geo_id', 'dl_speed'], length=216)

# %%
one=fcc_df[fcc_df['geo_id']=='0500000US06113']

# %%
20287+105+200108
# Out:
# 220500

# %%
one
# Out:
#              geo_id  dl_speed   has_0   has_1  has_2  has_3more  has_access  \
# 208  0500000US06113      25.0       0       1  13093     207406      220500
# 209  0500000US06113     100.0   29040   43801  92078      55581      191460
# 210  0500000US06113     250.0   73307  118380  27999        814      147193
# 211  0500000US06113    1000.0  134185   68699  17616          0       86315
#
#      total_pop  urban_pop  rural_pop  total_access_pop_percent  \
# 208     220500     200108      20392                  1.000000
# 209     220500     200108      20392                  0.868299
# 210     220500     200108      20392                  0.667542
# 211     220500     200108      20392                  0.391451
#
#      urban_access_pop_percent  rural_access_pop_percent
# 208                  1.000000                  1.000000
# 209                  0.940557                  0.159229
# 210                  0.730056                  0.054090
# ...
