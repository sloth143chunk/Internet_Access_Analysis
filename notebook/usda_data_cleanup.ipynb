# %%
# Dependencies and Setup
import pandas as pd
import os

# %%
# link to FCC data & create the first dataframe
usda_data = '../resources/usda/usda_rural_urban_codes_2013.csv'
usda_df = pd.read_csv(usda_data)
usda_df.head()
# Out:
#      FIPS State     County_Name Population_2010  RUCC_2013  \
# 0  1001.0    AL  Autauga County          54,571        2.0
# 1  1003.0    AL  Baldwin County         182,265        3.0
# 2  1005.0    AL  Barbour County          27,457        6.0
# 3  1007.0    AL     Bibb County          22,915        1.0
# 4  1009.0    AL   Blount County          57,322        1.0
#
#                                          Description
# 0  Metro - Counties in metro areas of 250,000 to ...
# 1  Metro - Counties in metro areas of fewer than ...
# 2  Nonmetro - Urban population of 2,500 to 19,999...
# 3  Metro - Counties in metro areas of 1 million p...
# 4  Metro - Counties in metro areas of 1 million p...

# %%
# determine state we should filter the data for
#user_input_state = input('Enter State Abbreviation (use two letter abbreviation):')
user_input_state = 'CA'

# %%
# filter for selected state and drop un needed columns
usda_df_one = usda_df.loc[usda_df["State"] == user_input_state, ]
usda_df_two = usda_df_one.drop(columns = ["State", "County_Name"])
usda_df_two.head()
# Out:
#        FIPS Population_2010  RUCC_2013  \
# 186  6001.0       1,510,271        1.0
# 187  6003.0           1,175        8.0
# 188  6005.0          38,091        6.0
# 189  6007.0         220,000        3.0
# 190  6009.0          45,578        6.0
#
#                                            Description
# 186  Metro - Counties in metro areas of 1 million p...
# 187  Nonmetro - Completely rural or less than 2,500...
# 188  Nonmetro - Urban population of 2,500 to 19,999...
# 189  Metro - Counties in metro areas of fewer than ...
# 190  Nonmetro - Urban population of 2,500 to 19,999...

# %%
#check data types
usda_df_two.dtypes
# Out:
# FIPS               float64
# Population_2010     object
# RUCC_2013          float64
# Description         object
# dtype: object

# %%
# Change ID to a string
usda_df_two["FIPS"] = usda_df_two["FIPS"].astype("int")
usda_df_two["FIPS"] = usda_df_two["FIPS"].astype("str")
usda_df_two["RUCC_2013"] = usda_df_two["RUCC_2013"].astype("int")
usda_df_two.dtypes
# Out:
# FIPS               object
# Population_2010    object
# RUCC_2013           int64
# Description        object
# dtype: object

# %%
usda_df_two.head()
# Out:
#      FIPS Population_2010  RUCC_2013  \
# 186  6001       1,510,271          1
# 187  6003           1,175          8
# 188  6005          38,091          6
# 189  6007         220,000          3
# 190  6009          45,578          6
#
#                                            Description
# 186  Metro - Counties in metro areas of 1 million p...
# 187  Nonmetro - Completely rural or less than 2,500...
# 188  Nonmetro - Urban population of 2,500 to 19,999...
# 189  Metro - Counties in metro areas of fewer than ...
# 190  Nonmetro - Urban population of 2,500 to 19,999...

# %%
# Add full geo_id to join w/ census tables using sql
usda_df_two["FIPS"] = "0500000US0" + usda_df_two["FIPS"]
usda_df_two.head()
# Out:
#                FIPS Population_2010  RUCC_2013  \
# 186  0500000US06001       1,510,271          1
# 187  0500000US06003           1,175          8
# 188  0500000US06005          38,091          6
# 189  0500000US06007         220,000          3
# 190  0500000US06009          45,578          6
#
#                                            Description
# 186  Metro - Counties in metro areas of 1 million p...
# 187  Nonmetro - Completely rural or less than 2,500...
# 188  Nonmetro - Urban population of 2,500 to 19,999...
# 189  Metro - Counties in metro areas of fewer than ...
# 190  Nonmetro - Urban population of 2,500 to 19,999...

# %%
# Rename Columns
usda_df_two.rename(columns={'FIPS': 'geo_id', 'Population_2010': 'total_pop_2010', 'RUCC_2013': 'usda_id', 'Description': 'description'}, inplace=True)
usda_df_two.head()
# Out:
#              geo_id total_pop_2010  usda_id  \
# 186  0500000US06001      1,510,271        1
# 187  0500000US06003          1,175        8
# 188  0500000US06005         38,091        6
# 189  0500000US06007        220,000        3
# 190  0500000US06009         45,578        6
#
#                                            description
# 186  Metro - Counties in metro areas of 1 million p...
# 187  Nonmetro - Completely rural or less than 2,500...
# 188  Nonmetro - Urban population of 2,500 to 19,999...
# 189  Metro - Counties in metro areas of fewer than ...
# 190  Nonmetro - Urban population of 2,500 to 19,999...

# %%
# Export dfs as CSV files
usda_df_two.to_csv('../resources/usda/usda_rural_urban_density.csv', index=False)
