# %%
# %load_ext autoreload
# %autoreload 1

# %%
# Import libraries.
# pip install requests
import requests

# pip isntall pandas
import pandas as pd

# Import the API key.
from config import census_api_key

# %%
# Year and State for API pulls (this could change to user input fields)
#user_input_year = input('Enter year (current is 2018):')
year_value = '2018'


#user_input_state = input('Enter State (use * for all states):')
state_value = 'Claifornia'

# %%
# Pull census state data and county from API
# Use try except to confirm response is 200 and not 404
# OR use if code == 200 then data found else data not found
state_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?get=NAME&for=state:*&key={census_api_key}'

# Create request for state API
state_request = requests.get(state_api)

# Create list from requests
state_list = state_request.json()
print(state_list)
# Out:
# [['NAME', 'state'], ['Minnesota', '27'], ['Mississippi', '28'], ['Missouri', '29'], ['Montana', '30'], ['Nebraska', '31'], ['Nevada', '32'], ['New Hampshire', '33'], ['New Jersey', '34'], ['New Mexico', '35'], ['New York', '36'], ['North Carolina', '37'], ['North Dakota', '38'], ['Ohio', '39'], ['Oklahoma', '40'], ['Oregon', '41'], ['Pennsylvania', '42'], ['Rhode Island', '44'], ['South Carolina', '45'], ['South Dakota', '46'], ['Tennessee', '47'], ['Texas', '48'], ['Utah', '49'], ['Vermont', '50'], ['Virginia', '51'], ['West Virginia', '54'], ['Washington', '53'], ['Wisconsin', '55'], ['Wyoming', '56'], ['Puerto Rico', '72'], ['Alabama', '01'], ['Alaska', '02'], ['Arizona', '04'], ['Arkansas', '05'], ['California', '06'], ['Colorado', '08'], ['Connecticut', '09'], ['Delaware', '10'], ['District of Columbia', '11'], ['Florida', '12'], ['Georgia', '13'], ['Idaho', '16'], ['Hawaii', '15'], ['Illinois', '17'], ['Indiana', '18'], ['Iowa', '19'], ['Kansas', '20'], ['Kentucky', '21'], ['Lo
# ...

# %%
# Create dictionary for state list to use for other API calls
state_dict = {}
for l2 in state_list:
    key, value = l2
    state_dict[key] = value
print(state_dict)
# Out:
# {'NAME': 'state', 'Minnesota': '27', 'Mississippi': '28', 'Missouri': '29', 'Montana': '30', 'Nebraska': '31', 'Nevada': '32', 'New Hampshire': '33', 'New Jersey': '34', 'New Mexico': '35', 'New York': '36', 'North Carolina': '37', 'North Dakota': '38', 'Ohio': '39', 'Oklahoma': '40', 'Oregon': '41', 'Pennsylvania': '42', 'Rhode Island': '44', 'South Carolina': '45', 'South Dakota': '46', 'Tennessee': '47', 'Texas': '48', 'Utah': '49', 'Vermont': '50', 'Virginia': '51', 'West Virginia': '54', 'Washington': '53', 'Wisconsin': '55', 'Wyoming': '56', 'Puerto Rico': '72', 'Alabama': '01', 'Alaska': '02', 'Arizona': '04', 'Arkansas': '05', 'California': '06', 'Colorado': '08', 'Connecticut': '09', 'Delaware': '10', 'District of Columbia': '11', 'Florida': '12', 'Georgia': '13', 'Idaho': '16', 'Hawaii': '15', 'Illinois': '17', 'Indiana': '18', 'Iowa': '19', 'Kansas': '20', 'Kentucky': '21', 'Louisiana': '22', 'Maine': '23', 'Maryland': '24', 'Massachusetts': '25', 'Michigan': '26'}

# %%
# Print state code from state_value (or user input)
#state_dict[user_input_state]
state_dict[state_value]
# Out:
# '06'

# %%
# Pull census demographic data from API, create request, and create list using state dict
county_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?get=NAME&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
county_request = requests.get(county_api)
county_list = county_request.json()

census__population_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0001E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_population_request = requests.get(census__population_api)
census_population_list = census_population_request.json()

census_internet_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0150E,DP02_0151E,DP02_0152E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_internet_request = requests.get(census_internet_api)
census_internet_list = census_internet_request.json()

census_age_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0005E,DP05_0006E,DP05_0007E,DP05_0008E,DP05_0009E,DP05_0010E,DP05_0011E,DP05_0012E,DP05_0013E,DP05_0014E,DP05_0015E,DP05_0016E,DP05_0017E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_age_request = requests.get(census_age_api)
census_age_list = census_age_request.json()

census_sex_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0002E,DP05_0003E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_sex_request = requests.get(census_sex_api)
census_sex_list = census_sex_request.json()

census_income_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0051E,DP03_0052E,DP03_0053E,DP03_0054E,DP03_0055E,DP03_0056E,DP03_0057E,DP03_0058E,DP03_0059E,DP03_0060E,DP03_0061E,DP03_0062E,DP03_0063E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_income_request = requests.get(census_income_api)
census_income_list = census_income_request.json()

census_education_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0059PE,DP02_0060PE,DP02_0061PE,DP02_0062PE,DP02_0063PE,DP02_0064PE,DP02_0065PE&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_education_request = requests.get(census_education_api)
census_education_list = census_education_request.json()

census_race_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0070E,DP05_0071E,DP05_0076E,DP05_0079E,DP05_0080E,DP05_0078E,DP05_0081E,DP05_0082E,DP05_0083E,DP05_0085E,DP05_0084E,DP05_0077E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_race_request = requests.get(census_race_api)
census_race_list = census_race_request.json()

census_citizenship_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0086E,DP02_0087E,DP02_0092E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_citizenship_request = requests.get(census_citizenship_api)
census_citizenship_list = census_citizenship_request.json()

census_disability_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0072E,DP02_0074E,DP02_0076E,DP02_0073E,DP02_0075E,DP02_0077E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_disability_request = requests.get(census_disability_api)
census_disability_list = census_disability_request.json()

census_employment_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0003E,DP03_0004E,DP03_0005E,DP03_0007E,DP03_0009PE&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_employment_list = requests.get(census_employment_api)
census_employment_list = census_employment_list.json()

census_occupation_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0026E,DP03_0027E,DP03_0028E,DP03_0029E,DP03_0030E,DP03_0031E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_occupation_request = requests.get(census_occupation_api)
census_occupation_list = census_occupation_request.json()

census_industry_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0033E,DP03_0034E,DP03_0035E,DP03_0036E,DP03_0037E,DP03_0038E,DP03_0039E,DP03_0040E,DP03_0041E,DP03_0042E,DP03_0043E,DP03_0044E,DP03_0045E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_industry_request = requests.get(census_industry_api)
census_industry_list = census_industry_request.json()

census_family_structure_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0001E,DP02_0013E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_family_structure_request = requests.get(census_family_structure_api)
census_family_structure_list = census_family_structure_request.json()

# %%
print(census__population_api)
# Out:
# https://api.census.gov/data/2018/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0001E&for=county:*&in=state:06&key=c4922650af1ec523155c3c6aec47c5491288a40c

# %%
# Rename header columns for all tables
for index, sublist in enumerate(state_list):
    if sublist[0] == 'NAME':
        state_list[index][0] = 'state_name'
        state_list[index][1] = 'state_id'
        
#if 'NAME' in state_list[0][0]:
    #state_list[index][0] = 'state_name'
    #state_list[index][1] = 'state_id'

for index, sublist in enumerate(county_list):
    if sublist[0] == 'NAME':
        county_list[index][0] = 'county_name'
        county_list[index][1] = 'county_id'

for index, sublist in enumerate(census_population_list):
    if sublist[0] == 'GEO_ID':
        census_population_list[index][0] = 'geo_id'
        census_population_list[index][1] = 'county_name'
        census_population_list[index][2] = 'population'
        census_population_list[index][3] = 'state_id'
        census_population_list[index][4] = 'county_id'

for index, sublist in enumerate(census_internet_list):
    if sublist[0] == 'GEO_ID':
        census_internet_list[index][0] = 'geo_id'
        census_internet_list[index][1] = 'county_name'
        census_internet_list[index][2] = 'hh_with_computer_and_internet_total'
        census_internet_list[index][3] = 'hh_with_computer'
        census_internet_list[index][4] = 'hh_with_bb_internet_subscription'
        census_internet_list[index][5] = 'state_id'
        census_internet_list[index][6] = 'county_id'

for index, sublist in enumerate(census_age_list):
    if sublist[0] == 'GEO_ID':
        census_age_list[index][0] = 'geo_id'
        census_age_list[index][1] = 'county_name'
        census_age_list[index][2] = 'age_under_5'
        census_age_list[index][3] = 'age_5-9'
        census_age_list[index][4] = 'age_10-14'
        census_age_list[index][5] = 'age_15-19'
        census_age_list[index][6] = 'age_20-24'
        census_age_list[index][7] = 'age_25-34'
        census_age_list[index][8] = 'age_35-44'
        census_age_list[index][9] = 'age_45-54'
        census_age_list[index][10] = 'age_55-59'
        census_age_list[index][11] = 'age_60-64'
        census_age_list[index][12] = 'age_65-74'
        census_age_list[index][13] = 'age_75-84'
        census_age_list[index][14] = 'age_85_and_over'
        census_age_list[index][15] = 'state_id'
        census_age_list[index][16] = 'county_id'
    
for index, sublist in enumerate(census_sex_list):
    if sublist[0] == 'GEO_ID':
        census_sex_list[index][0] = 'geo_id'
        census_sex_list[index][1] = 'county_name'
        census_sex_list[index][2] = 'sex_total_men'
        census_sex_list[index][3] = 'sex_total_women'
        census_sex_list[index][4] = 'state_id'
        census_sex_list[index][5] = 'county_id'
        
for index, sublist in enumerate(census_income_list):
    if sublist[0] == 'GEO_ID':
        census_income_list[index][0] = 'geo_id'
        census_income_list[index][1] = 'county_name'
        census_income_list[index][2] = 'hh_with_income_total'
        census_income_list[index][3] = 'hh_with_income_less_than_10000'
        census_income_list[index][4] = 'hh_with_income_10000-14999'
        census_income_list[index][5] = 'hh_with_income_15000-24999'
        census_income_list[index][6] = 'hh_with_income_25000-34999'
        census_income_list[index][7] = 'hh_with_income_35000-49999'
        census_income_list[index][8] = 'hh_with_income50000-74999'
        census_income_list[index][9] = 'hh_with_income_75000-99999'
        census_income_list[index][10] = 'hh_with_income_100000-149999'
        census_income_list[index][11] = 'hh_with_income_150000-199999'
        census_income_list[index][12] = 'hh_with_income_200000_and_greater'
        census_income_list[index][13] = 'hh_median_income'
        census_income_list[index][14] = 'hh_mean_income'
        census_income_list[index][15] = 'state_id'
        census_income_list[index][16] = 'county_id'
        
for index, sublist in enumerate(census_education_list):
    if sublist[0] == 'GEO_ID':
        census_education_list[index][0] = 'geo_id'
        census_education_list[index][1] = 'county_name'
        census_education_list[index][2] = '%_eduction_population_25_and_over_less_than_9th_grade'
        census_education_list[index][3] = '%_eduction_population_25_and_over_9th-12th_no_diploma'
        census_education_list[index][4] = '%_eduction_population_25_and_over_high_school_graduate'
        census_education_list[index][5] = '%_eduction_population_25_and_over_some_college_no_degree'
        census_education_list[index][6] = '%_eduction_population_25_and_over_associates_degree'
        census_education_list[index][7] = '%_eduction_population_25_and_over_bachelors_degree'
        census_education_list[index][8] = '%_eduction_population_25_and_over_graduate_or_professional_degree'
        census_education_list[index][9] = 'state_id'
        census_education_list[index][10] = 'county_id'

        
for index, sublist in enumerate(census_race_list):
    if sublist[0] == 'GEO_ID':
        census_race_list[index][0] = 'geo_id'
        census_race_list[index][1] = 'county_name'
        census_race_list[index][2] = 'race_total_population'
        census_race_list[index][3] = 'race_hispanic_or_latino'
        census_race_list[index][4] = 'race_not_hispanic_or_latino'
        census_race_list[index][5] = 'race_american_indian_and_alaska_native'
        census_race_list[index][6] = 'race_asian'
        census_race_list[index][7] = 'race_black_or_african_american'
        census_race_list[index][8] = 'race_native_hawaiian_and_other_pacific_islander'
        census_race_list[index][9] = 'race_some_other_race'
        census_race_list[index][10] = 'race_two_or_more'
        census_race_list[index][11] = 'race_two_or_more_excluding_some_ther_and_three_or_more'
        census_race_list[index][12] = 'race_two_or_more_including_some_other'
        census_race_list[index][13] = 'race_white_alone'
        census_race_list[index][14] = 'state_id'
        census_race_list[index][15] = 'county_id'
        
for index, sublist in enumerate(census_citizenship_list):
    if sublist[0] == 'GEO_ID':
        census_citizenship_list[index][0] = 'geo_id'
        census_citizenship_list[index][1] = 'county_name'
        census_citizenship_list[index][2] = 'citizenship_total_population'
        census_citizenship_list[index][3] = 'citizenship_native_born'
        census_citizenship_list[index][4] = 'citizenship_foreign_born'
        census_citizenship_list[index][5] = 'state_id'
        census_citizenship_list[index][6] = 'county_id'
        
for index, sublist in enumerate(census_disability_list):
    if sublist[0] == 'GEO_ID':
        census_disability_list[index][0] = 'geo_id'
        census_disability_list[index][1] = 'county_name'
        census_disability_list[index][2] = 'disability_population_under_18'
        census_disability_list[index][3] = 'disability_population_18-64'
        census_disability_list[index][4] = 'disability_population_65_and_over'
        census_disability_list[index][5] = 'disability_under_18_with_disability'
        census_disability_list[index][6] = 'disability_18-64_with_disability'
        census_disability_list[index][7] = 'disability_64_and_over_with_disability'
        census_disability_list[index][8] = 'state_id'
        census_disability_list[index][9] = 'county_id'
        
for index, sublist in enumerate(census_employment_list):
    if sublist[0] == 'GEO_ID':
        census_employment_list[index][0] = 'geo_id'
        census_employment_list[index][1] = 'county_name'
        census_employment_list[index][2] = 'employment_16_and_over_in_labor_force'
        census_employment_list[index][3] = 'employment_employed'
        census_employment_list[index][4] = 'employment_unemployed'
        census_employment_list[index][5] = 'employment_not_in_labor_force'
        census_employment_list[index][6] = 'employment_%_unemployment_rate'
        census_employment_list[index][7] = 'state_id'
        census_employment_list[index][8] = 'county_id'
        
for index, sublist in enumerate(census_occupation_list):
    if sublist[0] == 'GEO_ID':
        census_occupation_list[index][0] = 'geo_id'
        census_occupation_list[index][1] = 'county_name'
        census_occupation_list[index][2] = 'occupation_population_16_and_over_total'
        census_occupation_list[index][3] = 'occupation_management_business_science_and_arts'
        census_occupation_list[index][4] = 'occupation_service'
        census_occupation_list[index][5] = 'occupation_sales_and_office'
        census_occupation_list[index][6] = 'occupation_natural_resources_construction_and_maintenance'
        census_occupation_list[index][7] = 'occupation_production_transporation_and_material_moving'
        census_occupation_list[index][8] = 'state_id'
        census_occupation_list[index][9] = 'county_id'
        
for index, sublist in enumerate(census_industry_list):
    if sublist[0] == 'GEO_ID':
        census_industry_list[index][0] = 'geo_id'
        census_industry_list[index][1] = 'county_name'
        census_industry_list[index][2] = 'industry_agriculture_forestry_fishing_and_hunting_and_mining'
        census_industry_list[index][3] = 'industry_construction'
        census_industry_list[index][4] = 'industry_manufacturing'
        census_industry_list[index][5] = 'industry_wholesale_trade'
        census_industry_list[index][6] = 'industry_retail_trade'
        census_industry_list[index][7] = 'industry_transportation_and_warehousing_and_utilities'
        census_industry_list[index][8] = 'industry_information'
        census_industry_list[index][9] = 'industry_finance_and_insurance_real_estate_and_rental_and_leasing'
        census_industry_list[index][10] = 'industry_professional_scientific_management_administrative_and_waste_management_services'
        census_industry_list[index][11] = 'industry_educational_services_health_care_and_social_assistance'
        census_industry_list[index][12] = 'industry_arts_entertainment_recreation_accommodation_and_food services'
        census_industry_list[index][13] = 'industry_other_services_except_public_administration'
        census_industry_list[index][14] = 'industry_public_administration'
        census_industry_list[index][15] = 'state_id'
        census_industry_list[index][16] = 'county_id'
        
for index, sublist in enumerate(census_family_structure_list):
    if sublist[0] == 'GEO_ID':
        census_family_structure_list[index][0] = 'geo_id'
        census_family_structure_list[index][1] = 'county_name'
        census_family_structure_list[index][2] = 'family_structure_hh_total'
        census_family_structure_list[index][3] = 'family_structure_hh_with_one_or_more_under_18'
        census_family_structure_list[index][4] = 'state_id'
        census_family_structure_list[index][5] = 'county_id'

# %%
# Create DataFrames for all API lists
#Need to add key:value for * so this can be run for all states
state_df = pd.DataFrame(state_list)
county_df = pd.DataFrame(county_list)
census_population_df = pd.DataFrame(census_population_list)
census_internet_df = pd.DataFrame(census_internet_list)
census_age_df = pd.DataFrame(census_age_list)
census_sex_df = pd.DataFrame(census_sex_list)
census_income_df = pd.DataFrame(census_income_list)
census_education_df = pd.DataFrame(census_education_list)
census_race_df = pd.DataFrame(census_race_list)
census_citizenship_df = pd.DataFrame(census_citizenship_list)
census_disability_df = pd.DataFrame(census_disability_list)
census_employment_df = pd.DataFrame(census_employment_list)
census_occupation_df = pd.DataFrame(census_occupation_list)
census_industry_df = pd.DataFrame(census_industry_list)
census_family_structure_df = pd.DataFrame(census_family_structure_list)

# %%
# Make index 0 header for all DFs
# Reference: https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row
new_header_state = state_df.iloc[0]
state_df = state_df[1:]
state_df.columns = new_header_state

# Order columns for state_df & sort
state_df = state_df.reindex(columns=['state_id','state_name'])
#Sort_values is not working, tried changing type to float or int, but still does not work.
#state_df["state_id"] = state_df.state_id.astype(int)
#state_df.sort_values(by=['state_id'])
#state_df.dtypes

new_header_county = county_df.iloc[0]
county_df = county_df[1:]
county_df.columns = new_header_county
# Order columns for county_df & sort
state_df = state_df.reindex(columns=['county_id','county_name'])
#state_df.sort_values(by=['state_id'])

new_header_pop = census_population_df.iloc[0]
census_population_df = census_population_df[1:]
census_population_df.columns = new_header_pop

new_header_internet = census_internet_df.iloc[0]
census_internet_df = census_internet_df[1:]
census_internet_df.columns = new_header_internet

new_header_sex = census_sex_df.iloc[0]
census_sex_df = census_sex_df[1:]
census_sex_df.columns = new_header_sex

new_header_age = census_age_df.iloc[0]
census_age_df = census_age_df[1:]
census_age_df.columns = new_header_age

new_header_income = census_income_df.iloc[0]
census_income_df = census_income_df[1:]
census_income_df.columns = new_header_income

new_header_edu = census_education_df.iloc[0]
census_education_df = census_education_df[1:]
census_education_df.columns = new_header_edu

new_header_race = census_race_df.iloc[0]
census_race_df = census_race_df[1:]
census_race_df.columns = new_header_race

new_header_citizen = census_citizenship_df.iloc[0]
census_citizenship_df = census_citizenship_df[1:]
census_citizenship_df.columns = new_header_citizen

new_header_dis = census_disability_df.iloc[0]
census_disability_df = census_disability_df[1:]
census_disability_df.columns = new_header_dis

new_header_emp = census_employment_df.iloc[0]
census_employment_df = census_employment_df[1:]
census_employment_df.columns = new_header_emp

new_header_occu = census_occupation_df.iloc[0]
census_occupation_df = census_occupation_df[1:]
census_occupation_df.columns = new_header_occu

new_header_indus = census_industry_df.iloc[0]
census_industry_df = census_industry_df[1:]
census_industry_df.columns = new_header_indus

new_header_fam = census_family_structure_df.iloc[0]
census_family_structure_df = census_family_structure_df[1:]
census_family_structure_df.columns = new_header_fam

# %%
# Check df
census_family_structure_df.head()
census_industry_df.head()
# Out:
# 0          geo_id                      county_name  \
# 1  0500000US06033          Lake County, California
# 2  0500000US06043      Mariposa County, California
# 3  0500000US06115          Yuba County, California
# 4  0500000US06013  Contra Costa County, California
# 5  0500000US06035        Lassen County, California
#
# 0 industry_agriculture_forestry_fishing_and_hunting_and_mining  \
# 1                                               1658
# 2                                                270
# 3                                               1230
# 4                                               3698
# 5                                                585
#
# 0 industry_construction industry_manufacturing industry_wholesale_trade  \
# 1                  2083                    909                      382
# 2                   304                    348                       92
# 3                  2700                   1689                      698
# ...

# %%
# Export all DataFrames as CSV files
state_df.to_csv('../resources/census_api/state.csv', index=False)
county_df.to_csv('../resources/census_api/county.csv', index=False)
census_population_df.to_csv('../resources/census_api/census_population_data.csv', index=False)
census_internet_df.to_csv('../resources/census_api/census_internet_data.csv', index=False)
census_age_df.to_csv('../resources/census_api/census_age_data.csv', index=False)
census_sex_df.to_csv('../resources/census_api/census_sex_data.csv', index=False)
census_income_df.to_csv('../resources/census_api/census_income_data.csv', index=False)
census_education_df.to_csv('../resources/census_api/census_education_data.csv', index=False)
census_race_df.to_csv('../resources/census_api/census_race_data.csv', index=False)
census_citizenship_df.to_csv('../resources/census_api/census_citizenship_data.csv', index=False)
census_disability_df.to_csv('../resources/census_api/census_disability_data.csv', index=False)
census_employment_df.to_csv('../resources/census_api/census_employment_data.csv', index=False)
census_industry_df.to_csv('../resources/census_api/census_industry_data.csv', index=False)
census_occupation_df.to_csv('../resources/census_api/census_occupation_data.csv', index=False)
census_family_structure_df.to_csv('../resources/census_api/census_family_structure_data.csv', index=False)
