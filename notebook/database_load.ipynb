# %%
# %load_ext autoreload
# %autoreload 1

# %%
# Import libraries.
# pip install requests
import requests

# pip isntall pandas
import pandas as pd

# User will need their own config.py file with api_key, user & password database credentials
# Import the API key.
from config import census_api_key
# AWS Credentials
from config import aws_user
from config import aws_password

# %%
# Year and State for API pulls (this could change to user input fields)
#user_input_year = input('Enter year (current is 2018):')
year_value = '2018'

#user_input_state = input('Enter State (use * for all states):')
state_value = 'California'

# %%
# Pull census state data and county from API
# Use try except to confirm response is 200 and not 404
# OR use if code == 200 then data found else data not found
state_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?get=NAME&for=state:*&key={census_api_key}'

# Create request for state API
state_request = requests.get(state_api)

# Create list from requests
state_list = state_request.json()

# %%
# Create dictionary for state list to use for other API calls
state_dict = {}
for l2 in state_list:
    key, value = l2
    state_dict[key] = value

# %%
# Pull census demographic data from API, create request, and create list using state dict
county_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?get=GEO_ID,NAME&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
county_request = requests.get(county_api)
county_list = county_request.json()

census_population_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0001E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_population_request = requests.get(census_population_api)
census_population_list = census_population_request.json()

census_internet_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0150E,DP02_0151E,DP02_0152E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_internet_request = requests.get(census_internet_api)
census_internet_list = census_internet_request.json()

census_age_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0005E,DP05_0006E,DP05_0007E,DP05_0008E,DP05_0009E,DP05_0010E,DP05_0011E,DP05_0012E,DP05_0013E,DP05_0014E,DP05_0015E,DP05_0016E,DP05_0017E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_age_request = requests.get(census_age_api)
census_age_list = census_age_request.json()

census_sex_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0002E,DP05_0003E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_sex_request = requests.get(census_sex_api)
census_sex_list = census_sex_request.json()

census_income_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0051E,DP03_0052E,DP03_0053E,DP03_0054E,DP03_0055E,DP03_0056E,DP03_0057E,DP03_0058E,DP03_0059E,DP03_0060E,DP03_0061E,DP03_0062E,DP03_0063E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_income_request = requests.get(census_income_api)
census_income_list = census_income_request.json()

census_education_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0059PE,DP02_0060PE,DP02_0061PE,DP02_0062PE,DP02_0063PE,DP02_0064PE,DP02_0065PE&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_education_request = requests.get(census_education_api)
census_education_list = census_education_request.json()

census_race_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP05_0070E,DP05_0071E,DP05_0076E,DP05_0079E,DP05_0080E,DP05_0078E,DP05_0081E,DP05_0082E,DP05_0083E,DP05_0085E,DP05_0084E,DP05_0077E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_race_request = requests.get(census_race_api)
census_race_list = census_race_request.json()

census_citizenship_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0086E,DP02_0087E,DP02_0092E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_citizenship_request = requests.get(census_citizenship_api)
census_citizenship_list = census_citizenship_request.json()

census_disability_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0072E,DP02_0074E,DP02_0076E,DP02_0073E,DP02_0075E,DP02_0077E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_disability_request = requests.get(census_disability_api)
census_disability_list = census_disability_request.json()

census_employment_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0003E,DP03_0004E,DP03_0005E,DP03_0007E,DP03_0009PE&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_employment_list = requests.get(census_employment_api)
census_employment_list = census_employment_list.json()

census_occupation_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0026E,DP03_0027E,DP03_0028E,DP03_0029E,DP03_0030E,DP03_0031E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_occupation_request = requests.get(census_occupation_api)
census_occupation_list = census_occupation_request.json()

census_industry_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP03_0033E,DP03_0034E,DP03_0035E,DP03_0036E,DP03_0037E,DP03_0038E,DP03_0039E,DP03_0040E,DP03_0041E,DP03_0042E,DP03_0043E,DP03_0044E,DP03_0045E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_industry_request = requests.get(census_industry_api)
census_industry_list = census_industry_request.json()

census_family_structure_api = f'https://api.census.gov/data/{year_value}/acs/acs5/profile?&get=GEO_ID,NAME,DP02_0001E,DP02_0013E&for=county:*&in=state:{state_dict[state_value]}&key={census_api_key}'
census_family_structure_request = requests.get(census_family_structure_api)
census_family_structure_list = census_family_structure_request.json()

# %%
# Rename header columns for all tables (refactored)
if 'NAME' in state_list[0][0]:
    state_list[0][0] = 'state_name'
    state_list[0][1] = 'state_id'

if 'GEO_ID' in county_list[0][0]:
    county_list[0][0] = 'geo_id'
    county_list[0][1] = 'county_name'
    county_list[0][2] = 'state_id'
    county_list[0][3] = 'county_id'

if 'GEO_ID' in census_population_list[0][0]:
    census_population_list[0][0] = 'geo_id'
    census_population_list[0][1] = 'county_name'
    census_population_list[0][2] = 'population'
    census_population_list[0][3] = 'state_id'
    census_population_list[0][4] = 'county_id'
    
if 'GEO_ID' in census_internet_list[0][0]:
    census_internet_list[0][0] = 'geo_id'
    census_internet_list[0][1] = 'county_name'
    census_internet_list[0][2] = 'hh_with_computer_and_internet_total'
    census_internet_list[0][3] = 'hh_with_computer'
    census_internet_list[0][4] = 'hh_with_bb_internet_subscription'
    census_internet_list[0][5] = 'state_id'
    census_internet_list[0][6] = 'county_id'
    
if 'GEO_ID' in census_age_list[0][0]:
    census_age_list[0][0] = 'geo_id'
    census_age_list[0][1] = 'county_name'
    census_age_list[0][2] = 'age_under_5'
    census_age_list[0][3] = 'age_5-9'
    census_age_list[0][4] = 'age_10-14'
    census_age_list[0][5] = 'age_15-19'
    census_age_list[0][6] = 'age_20-24'
    census_age_list[0][7] = 'age_25-34'
    census_age_list[0][8] = 'age_35-44'
    census_age_list[0][9] = 'age_45-54'
    census_age_list[0][10] = 'age_55-59'
    census_age_list[0][11] = 'age_60-64'
    census_age_list[0][12] = 'age_65-74'
    census_age_list[0][13] = 'age_75-84'
    census_age_list[0][14] = 'age_85_and_over'
    census_age_list[0][15] = 'state_id'
    census_age_list[0][16] = 'county_id'
        
if 'GEO_ID' in census_sex_list[0][0]:
    census_sex_list[0][0] = 'geo_id'
    census_sex_list[0][1] = 'county_name'
    census_sex_list[0][2] = 'sex_total_men'
    census_sex_list[0][3] = 'sex_total_women'
    census_sex_list[0][4] = 'state_id'
    census_sex_list[0][5] = 'county_id'
        
if 'GEO_ID' in census_income_list[0][0]:
    census_income_list[0][0] = 'geo_id'
    census_income_list[0][1] = 'county_name'
    census_income_list[0][2] = 'hh_with_income_total'
    census_income_list[0][3] = 'hh_with_income_less_than_10000'
    census_income_list[0][4] = 'hh_with_income_10000-14999'
    census_income_list[0][5] = 'hh_with_income_15000-24999'
    census_income_list[0][6] = 'hh_with_income_25000-34999'
    census_income_list[0][7] = 'hh_with_income_35000-49999'
    census_income_list[0][8] = 'hh_with_income50000-74999'
    census_income_list[0][9] = 'hh_with_income_75000-99999'
    census_income_list[0][10] = 'hh_with_income_100000-149999'
    census_income_list[0][11] = 'hh_with_income_150000-199999'
    census_income_list[0][12] = 'hh_with_income_200000_and_greater'
    census_income_list[0][13] = 'hh_median_income'
    census_income_list[0][14] = 'hh_mean_income'
    census_income_list[0][15] = 'state_id'
    census_income_list[0][16] = 'county_id'
        
if 'GEO_ID' in census_education_list[0][0]:
    census_education_list[0][0] = 'geo_id'
    census_education_list[0][1] = 'county_name'
    census_education_list[0][2] = '%_eduction_population_25_and_over_less_than_9th_grade'
    census_education_list[0][3] = '%_eduction_population_25_and_over_9th-12th_no_diploma'
    census_education_list[0][4] = '%_eduction_population_25_and_over_high_school_graduate'
    census_education_list[0][5] = '%_eduction_population_25_and_over_some_college_no_degree'
    census_education_list[0][6] = '%_eduction_population_25_and_over_associates_degree'
    census_education_list[0][7] = '%_eduction_population_25_and_over_bachelors_degree'
    census_education_list[0][8] = '%_eduction_population_25_and_over_graduate_or_professional_degree'
    census_education_list[0][9] = 'state_id'
    census_education_list[0][10] = 'county_id'
    
if 'GEO_ID' in census_race_list[0][0]:
    census_race_list[0][0] = 'geo_id'
    census_race_list[0][1] = 'county_name'
    census_race_list[0][2] = 'race_total_population'
    census_race_list[0][3] = 'race_hispanic_or_latino'
    census_race_list[0][4] = 'race_not_hispanic_or_latino'
    census_race_list[0][5] = 'race_american_indian_and_alaska_native'
    census_race_list[0][6] = 'race_asian'
    census_race_list[0][7] = 'race_black_or_african_american'
    census_race_list[0][8] = 'race_native_hawaiian_and_other_pacific_islander'
    census_race_list[0][9] = 'race_some_other_race'
    census_race_list[0][10] = 'race_two_or_more'
    census_race_list[0][11] = 'race_two_or_more_excluding_some_ther_and_three_or_more'
    census_race_list[0][12] = 'race_two_or_more_including_some_other'
    census_race_list[0][13] = 'race_white_alone'
    census_race_list[0][14] = 'state_id'
    census_race_list[0][15] = 'county_id'
    
if 'GEO_ID' in census_citizenship_list[0][0]:
    census_citizenship_list[0][0] = 'geo_id'
    census_citizenship_list[0][1] = 'county_name'
    census_citizenship_list[0][2] = 'citizenship_total_population'
    census_citizenship_list[0][3] = 'citizenship_native_born'
    census_citizenship_list[0][4] = 'citizenship_foreign_born'
    census_citizenship_list[0][5] = 'state_id'
    census_citizenship_list[0][6] = 'county_id'
    
if 'GEO_ID' in census_disability_list[0][0]:
    census_disability_list[0][0] = 'geo_id'
    census_disability_list[0][1] = 'county_name'
    census_disability_list[0][2] = 'disability_population_under_18'
    census_disability_list[0][3] = 'disability_population_18-64'
    census_disability_list[0][4] = 'disability_population_65_and_over'
    census_disability_list[0][5] = 'disability_under_18_with_disability'
    census_disability_list[0][6] = 'disability_18-64_with_disability'
    census_disability_list[0][7] = 'disability_64_and_over_with_disability'
    census_disability_list[0][8] = 'state_id'
    census_disability_list[0][9] = 'county_id'

if 'GEO_ID' in census_employment_list[0][0]:
    census_employment_list[0][0] = 'geo_id'
    census_employment_list[0][1] = 'county_name'
    census_employment_list[0][2] = 'employment_16_and_over_in_labor_force'
    census_employment_list[0][3] = 'employment_employed'
    census_employment_list[0][4] = 'employment_unemployed'
    census_employment_list[0][5] = 'employment_not_in_labor_force'
    census_employment_list[0][6] = 'employment_%_unemployment_rate'
    census_employment_list[0][7] = 'state_id'
    census_employment_list[0][8] = 'county_id'
    
if 'GEO_ID' in census_occupation_list[0][0]:
    census_occupation_list[0][0] = 'geo_id'
    census_occupation_list[0][1] = 'county_name'
    census_occupation_list[0][2] = 'occupation_population_16_and_over_total'
    census_occupation_list[0][3] = 'occupation_management_business_science_and_arts'
    census_occupation_list[0][4] = 'occupation_service'
    census_occupation_list[0][5] = 'occupation_sales_and_office'
    census_occupation_list[0][6] = 'occupation_natural_resources_construction_and_maintenance'
    census_occupation_list[0][7] = 'occupation_production_transporation_and_material_moving'
    census_occupation_list[0][8] = 'state_id'
    census_occupation_list[0][9] = 'county_id'
    
if 'GEO_ID' in census_industry_list[0][0]:
    census_industry_list[0][0] = 'geo_id'
    census_industry_list[0][1] = 'county_name'
    census_industry_list[0][2] = 'industry_agriculture_forestry_fishing_and_hunting_and_mining'
    census_industry_list[0][3] = 'industry_construction'
    census_industry_list[0][4] = 'industry_manufacturing'
    census_industry_list[0][5] = 'industry_wholesale_trade'
    census_industry_list[0][6] = 'industry_retail_trade'
    census_industry_list[0][7] = 'industry_transportation_and_warehousing_and_utilities'
    census_industry_list[0][8] = 'industry_information'
    census_industry_list[0][9] = 'industry_finance_and_insurance_real_estate_and_rental_and_leasing'
    census_industry_list[0][10] = 'industry_professional_scientific_management_administrative_and_waste_management_services'
    census_industry_list[0][11] = 'industry_educational_services_health_care_and_social_assistance'
    census_industry_list[0][12] = 'industry_arts_entertainment_recreation_accommodation_and_food_services'
    census_industry_list[0][13] = 'industry_other_services_except_public_administration'
    census_industry_list[0][14] = 'industry_public_administration'
    census_industry_list[0][15] = 'state_id'
    census_industry_list[0][16] = 'county_id'
    
if 'GEO_ID' in census_family_structure_list[0][0]:
    census_family_structure_list[0][0] = 'geo_id'
    census_family_structure_list[0][1] = 'county_name'
    census_family_structure_list[0][2] = 'family_structure_hh_total'
    census_family_structure_list[0][3] = 'family_structure_hh_with_one_or_more_under_18'
    census_family_structure_list[0][4] = 'state_id'
    census_family_structure_list[0][5] = 'county_id'

# %%
# Create DataFrames for all API lists (refactored to have first array be header)
#Need to add key:value for * so this can be run for all states
state_df = pd.DataFrame(state_list[1:],columns=state_list[0])
county_df = pd.DataFrame(county_list[1:],columns=county_list[0])
census_population_df = pd.DataFrame(census_population_list[1:],columns=census_population_list[0])
census_internet_df = pd.DataFrame(census_internet_list[1:],columns=census_internet_list[0])
census_age_df = pd.DataFrame(census_age_list[1:],columns=census_age_list[0])
census_sex_df = pd.DataFrame(census_sex_list[1:],columns=census_sex_list[0])
census_income_df = pd.DataFrame(census_income_list[1:],columns=census_income_list[0])
census_education_df = pd.DataFrame(census_education_list[1:],columns=census_education_list[0])
census_race_df = pd.DataFrame(census_race_list[1:],columns=census_race_list[0])
census_citizenship_df = pd.DataFrame(census_citizenship_list[1:],columns=census_citizenship_list[0])
census_disability_df = pd.DataFrame(census_disability_list[1:],columns=census_disability_list[0])
census_employment_df = pd.DataFrame(census_employment_list[1:],columns=census_employment_list[0])
census_occupation_df = pd.DataFrame(census_occupation_list[1:],columns=census_occupation_list[0])
census_industry_df = pd.DataFrame(census_industry_list[1:],columns=census_industry_list[0])
census_family_structure_df = pd.DataFrame(census_family_structure_list[1:],columns=census_family_structure_list[0])

# %%
# Export all DataFrames as CSV files
state_df.to_csv('../resources/census_api/state.csv', index=False)
county_df.to_csv('../resources/census_api/county.csv', index=False)
census_population_df.to_csv('../resources/census_api/census_population_data.csv', index=False)
census_internet_df.to_csv('../resources/census_api/census_internet_data.csv', index=False)
census_age_df.to_csv('../resources/census_api/census_age_data.csv', index=False)
census_sex_df.to_csv('../resources/census_api/census_sex_data.csv', index=False)
census_income_df.to_csv('../resources/census_api/census_income_data.csv', index=False)
census_education_df.to_csv('../resources/census_api/census_education_data.csv', index=False)
census_race_df.to_csv('../resources/census_api/census_race_data.csv', index=False)
census_citizenship_df.to_csv('../resources/census_api/census_citizenship_data.csv', index=False)
census_disability_df.to_csv('../resources/census_api/census_disability_data.csv', index=False)
census_employment_df.to_csv('../resources/census_api/census_employment_data.csv', index=False)
census_industry_df.to_csv('../resources/census_api/census_industry_data.csv', index=False)
census_occupation_df.to_csv('../resources/census_api/census_occupation_data.csv', index=False)
census_family_structure_df.to_csv('../resources/census_api/census_family_structure_data.csv', index=False)

# %%
# Download the Postgres driver that will allow Spark to interact with Postgres.
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# /bin/bash: wget: command not found

# %%
# Load FCC csv / combine code with census_api?

# If loading csv then bring is as DataFrames

# %%
# Configure settings for RDS
mode = "overwrite"
jdbc_url="jdbc:postgresql://<connection string>:5432/<database-name>"
config = {"user":aws_user,
          "password": aws_password,
          "driver":"org.postgresql.Driver"}

# %%
# Create SQL Tables
# if table exists then:
#     do nothing
#     else Create table
    
# Use QuickDB print out for easy table creation

# %%
# Write DataFrames to SQL Tables
state_df.write.jdbc(url=jdbc_url, table='census_state', mode=mode, properties=config)
county_df.write.jdbc(url=jdbc_url, table='census_county', mode=mode, properties=config)
census_population_df.write.jdbc(url=jdbc_url, table='census_population', mode=mode, properties=config)
census_internet_df.write.jdbc(url=jdbc_url, table='census_internet_access', mode=mode, properties=config)
census_age_df.write.jdbc(url=jdbc_url, table='census_age', mode=mode, properties=config)
census_sex_df.write.jdbc(url=jdbc_url, table='census_sex', mode=mode, properties=config)
census_income_df.write.jdbc(url=jdbc_url, table='census_income', mode=mode, properties=config)
census_race_df.write.jdbc(url=jdbc_url, table='census_race', mode=mode, properties=config)
census_citizenship_df.write.jdbc(url=jdbc_url, table='census_citizenship', mode=mode, properties=config)
census_disability_df.write.jdbc(url=jdbc_url, table='census_disability', mode=mode, properties=config)
census_employment_df.write.jdbc(url=jdbc_url, table='census_employment', mode=mode, properties=config)
census_industry_df.write.jdbc(url=jdbc_url, table='census_industry', mode=mode, properties=config)
census_occupation_df.write.jdbc(url=jdbc_url, table='census_occupation', mode=mode, properties=config)
census_family_structure_df.write.jdbc(url=jdbc_url, table='census_family_structure', mode=mode, properties=config)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2b1cfe2344a5> in <module>
#       1 # Write DataFrames to SQL Tables
# ----> 2 state_df.write.jdbc(url=jdbc_url, table='census_state', mode=mode, properties=config)
#       3 county_df.write.jdbc(url=jdbc_url, table='census_county', mode=mode, properties=config)
#       4 census_population_df.write.jdbc(url=jdbc_url, table='census_population', mode=mode, properties=config)
#       5 census_internet_df.write.jdbc(url=jdbc_url, table='census_internet_access', mode=mode, properties=config)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
# ...
